# %%
import datetime
import pandas as pd

df = pd.read_excel('./Files/budget.xlsx', sheet_name='Sheet1', index_col=0)

# %%
df
# Out:
#        wage  dividends  groceries  home_mortgage  home_insurance  \
# month
# JAN       0          0          0              0               0
# FEB       0          0          0              0               0
# MAR       0          0          0              0               0
# APR       0          0          0              0               0
# MAY    9631        640        600              0               0
# JUN    1690        500          0              0               0
# JUL    1690          0          0              0               0
# AUG    1691        350        505              0               0
# SEP       0          0          0              0               0
# OCT       0          0          0              0               0
# NOV       0          0          0              0               0
# DEC       0          0          0              0               0
#
#        home_repairs  home_bills  bus_fare  fuel  car_repair  ...  \
# ...

# %%
df.loc['AUG']
# Out:
# wage                     1691
# dividends                 350
# groceries                 505
# home_mortgage               0
# home_insurance              0
# home_repairs                0
# home_bills                  0
# bus_fare                    0
# fuel                        0
# car_repair                  0
# parking                     0
# hobbies                     0
# books_games                 0
# movies_concerts             0
# health_insurance            0
# medication                  0
# vacation_transport          0
# vacation_accomodation       0
# vacation_food               0
# phone_bill                  0
# internet                    0
# clothes                   150
# barber                     50
# toiletry                  222
# gifts                     100
# savings                   100
# tax                       230
# Name: AUG, dtype: int64

# %%
expenditure = df.loc['AUG'][2:].sum()
income = df.loc['AUG'][:2].sum()
spend = income - expenditure
